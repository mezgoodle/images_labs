# %%
common_path = '/content/drive/MyDrive/University/Third course/Sixth term/Images/Resources/'

# %%
error = 0.6

# %% [markdown]
# # First task

# %%
import dlib
from skimage import io
from scipy.spatial import distance

# %% [markdown]
# ## Create Models

# %%
shape_predictor = dlib.shape_predictor(common_path + 'shape_predictor_68_face_landmarks.dat')

# %%
face_recognition = dlib.face_recognition_model_v1(common_path + 'dlib_face_recognition_resnet_model_v1.dat')

# %%
detector = dlib.get_frontal_face_detector()

# %% [markdown]
# ## Read the first image

# %%
img = io.imread(common_path + 'Photos/camera.jpg')
dots = detector(img, 1)

# %% [markdown]
# ## Search dots on the first image

# %%
shape: None

# %%
def apply_dots(image, dots):
  for k, dot in enumerate(dots):
    print(f"Detection {k}: Left: {dot.left()} Top: {dot.top()} Right: {dot.right()} Bottom: {dot.bottom()}")
    shape = shape_predictor(image, dot)

# %%
apply_dots(img, dots)
# Out:
# Detection 0: Left: 236 Top: 133 Right: 390 Bottom: 288

# %%
first_face_descriptor = face_recognition.compute_face_descriptor(img, shape)

# %% [markdown]
# ## Read the second image

# %%
img = io.imread(common_path + 'Photos/passport.jpg')
dots = detector(img, 1)

# %% [markdown]
# ## Search dots on the second image

# %%
apply_dots(img, dots)
# Out:
# Detection 0: Left: 46 Top: 98 Right: 201 Bottom: 253

# %%
second_face_descriptor = face_recognition.compute_face_descriptor(img, shape)

# %%
result = distance.euclidean(first_face_descriptor, second_face_descriptor)

# %%
result < error
# Out:
# True

# %% [markdown]
# ### Summary
#
# As we can see, result **is less** that the error. So there is the same person on the both photos.

# %% [markdown]
# # Second task

# %%
import requests
import dlib
from scipy.spatial import distance
from skimage import io
from bs4 import BeautifulSoup
import numpy as np
import urllib.request
import cv2

# %% [markdown]
# ## Get the images from the site

# %%
url = "https://vtl.in.ua/937-2/"

# %%
page_data = requests.get(url, verify=False).text
# Out:
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ## Images array preprocessing

# %%
images_urls = [
    image.attrs.get("src")
    for image in BeautifulSoup(page_data, 'html.parser').find_all("img")
]
images_urls
# Out:
# ['https://vtl.in.ua/wp-content/uploads/2019/11/yefremenuk.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/01/ostashko-o.v.-scaled.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2019/11/shtelmah.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tomchuk-scaled.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2020/09/amm_i.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2020/11/platonov.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2019/11/volkov.jpg',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/facebook.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/foursquare.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/instagram.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/tagged.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/youtube.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611182834.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611226895.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611225004.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611182947.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611244735.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611224064.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611226465.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611227410.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611227728.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/11/diyaosvita.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/11/vseurkshkolaoonline.png']

# %%
images_urls = [
    image_url
    for image_url in images_urls
    if image_url and len(image_url) > 0
]
images_urls
# Out:
# ['https://vtl.in.ua/wp-content/uploads/2019/11/yefremenuk.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/01/ostashko-o.v.-scaled.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2019/11/shtelmah.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tomchuk-scaled.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2020/09/amm_i.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2020/11/platonov.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2019/11/volkov.jpg',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/facebook.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/foursquare.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/instagram.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/tagged.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/youtube.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611182834.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611226895.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611225004.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611182947.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611244735.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611224064.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611226465.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611227410.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611227728.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/11/diyaosvita.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/11/vseurkshkolaoonline.png']

# %%
for image in images_urls:
    if 'data:image' in image or '/content' in image:
      images_urls.remove(image)
images_urls
# Out:
# ['https://vtl.in.ua/wp-content/uploads/2019/11/yefremenuk.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/01/ostashko-o.v.-scaled.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2019/11/shtelmah.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tomchuk-scaled.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2020/09/amm_i.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2020/11/platonov.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2019/11/volkov.jpg',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/facebook.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/foursquare.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/instagram.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/tagged.png',
#  'https://vtl.in.ua/wp-content/plugins/accesspress-social-icons/icon-sets/png/set9/youtube.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611182834.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611226895.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611225004.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611182947.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611244735.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611224064.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611226465.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611227410.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tiger-1611227728.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/11/diyaosvita.png',
#  'https://vtl.in.ua/wp-content/uploads/2021/11/vseurkshkolaoonline.png']

# %% [markdown]
# Delete logos from array list

# %%
images_urls = images_urls[:7]
images_urls
# Out:
# ['https://vtl.in.ua/wp-content/uploads/2019/11/yefremenuk.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/01/ostashko-o.v.-scaled.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2019/11/shtelmah.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2021/03/tomchuk-scaled.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2020/09/amm_i.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2020/11/platonov.jpg',
#  'https://vtl.in.ua/wp-content/uploads/2019/11/volkov.jpg']

# %%
len(images_urls)
# Out:
# 7

# %%
def url_to_image(url):
    import ssl
    ctx = ssl.create_default_context()
    ctx.check_hostname = False
    ctx.verify_mode = ssl.CERT_NONE

    resp = urllib.request.urlopen(url, context=ctx)
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    return image

# %% [markdown]
# ## Start the analysis

# %%
dictionary_data = {}

# %%
shape_predictor = dlib.shape_predictor(common_path + 'shape_predictor_68_face_landmarks.dat')

# %%
face_recognition = dlib.face_recognition_model_v1(common_path + 'dlib_face_recognition_resnet_model_v1.dat')

# %%
detector = dlib.get_frontal_face_detector()

# %% [markdown]
# ## Creating the dictionary with dotted images

# %%
for image in images_urls:
    img = url_to_image(image)

    dots = detector(img, 1)
    shape: None

    for k, dot in enumerate(dots):
        shape = shape_predictor(img, dot)

    face_descriptor = face_recognition.compute_face_descriptor(img, shape)

    dictionary_data[image[52:len(image)].partition('-')[0]] = face_descriptor

# %%
dictionary_data
# Out:
# {'': dlib.vector([-0.135775, 0.0449008, 0.065291, -0.00143909, -0.152883, -0.0683684, 0.0159864, -0.142866, 0.191747, -0.115335, 0.113714, -0.129597, -0.349116, 0.0503004, 0.00386629, 0.169436, -0.110493, -0.185223, -0.0782937, -0.0122106, 0.0720401, 0.122127, -0.0335792, 0.0955429, -0.0751047, -0.352675, -0.080513, -0.123994, -0.100852, -0.0688328, -0.0330355, 0.0939833, -0.124089, -0.0435393, 0.0378406, 0.130664, -0.0519156, -0.125738, 0.189056, -0.0397784, -0.307618, -0.0941732, 0.118938, 0.212634, 0.195948, -0.0224884, -0.0695167, -0.067027, 0.136152, -0.326649, -0.0932788, 0.142792, 0.0672716, 0.0935185, 0.0763459, -0.215365, 0.00793821, 0.0900042, -0.257995, 0.0321719, 0.0499221, -0.220111, 0.0078807, -0.0474929, 0.200948, 0.085303, -0.102878, -0.062664, 0.140269, -0.227272, -0.0303269, 0.115988, -0.146483, -0.265043, -0.25034,
923816, 0.15416, -0.107857, -0.0798318, -0.0692737, 0.0301917, 0.157935, -0.0105631, -0.0127848, 0.234862, 0.0697405, 0.0387195, 0.0728915, 0.110891, -0.130997, 0.00553127, -0.166908, -0.00826083, 0.0483412, -0.038238, 0.00151049, 0.136225, -0.139304, 0.195271, -0.0481869, -0.00493851, 0.0482906, -0.0931583, -0.0482745, -0.0934139, 0.0920807, -0.268839, 0.0753773, 0.158432, 0.0619631, 0.183275, 0.0437951, 0.0431443, 0.00724404, -0.0616588, -0.204791, -0.0371158, 0.00122647, 0.0142923, -0.0792881, 0.0249009]),
#  'v.jpg': dlib.vector([-0.135874, -0.00276139, 0.0223444, -0.138892, -0.168486, -0.0679705, -0.0486316, -0.0377385, 0.0930112, -0.141249, 0.111004, -0.0246887, -0.188381, -0.0443804, 0.0757524, 0.121749, -0.206508, -0.13797, -0.087503, -0.0639454, 0.00572029, 0.0505961, 0.0229744, 0.0335617, -0.0973394, -0.275818, -0.0852547, -0.0848324, -0.0484882, -0.00386415, 0.0152914, 0.0289669, -0.142472, -0.0287779, -0.0293229, 0.0548694, -0.125999, -0.0716645, 0.22239, 0.0643242, -0.203861, -0.0191352, -0.0068315, 0.261143, 0.211307, 0.0252339, 0.0418364, 0.000376372, 0.127976, -0.318817, 0.131814, 0.168119, 0.0892151, 0.0135299, 0.0851569, -0.108014, 0.0555308, 0.136071, -0.129298, 0.0366141, 0.111437, -0.057629, -0.0260053, -0.0529692, 0.252593, 0.15842, -0.095124, -0.0660795, 0.171856, -0.0785523, -0.155984, -0.00453069, -0.159953, -0.178443, -0.255559, 0.0371099, 0.32726, 0.134664, -0.16996, -0.00125749, -0.0431681, 0.0351928, 0.131093, 0.109626, -0.0969081, -0.00818388, -0.0888922, 0.04245, 0.149828, -0.0639933, -0.0712991, 0.210151, 0.114558, -0.0075736, 0.100678, -0.00239755, 0.020318, -0.0341827, -0.15999, 0.0272481, 0.145075, -0.0936782, -0.0354847, 0.107616, -0.128394, 0.193976, -0.00355296, -0.0198957, -0.0734463, -0.0534146, -0.0859243, -0.00160106, 0.102793, -0.135064, 0.132545, 0.15674, -0.0166077, 0.179281, 0.0799832, 0.0617215, -0.042534, -0.0240985, -0.185063, -0.0761841, 0.0963176, 0.119297, 0.0879094, 0.127509])}

# %%
img = io.imread(common_path + 'Photos/ped_kol.jpg')

# %%
dets = detector(img, 1)

# %%
print(f'Знайдено {len(dets)} облич.')
# Out:
# Знайдено 18 облич.

# %%
number_of_faces = 0

# %%
for k, det in enumerate(dets):
  for key in dictionary_data:
    shape = shape_predictor(img, det)
    face_descriptor = face_recognition.compute_face_descriptor(img, shape)
    result = distance.euclidean(dictionary_data[key], face_descriptor)
    if result < error:
      number_of_faces += 1

# %%
print(f'Кількість виявлених облич на фото: {number_of_faces}')
# Out:
# Кількість виявлених облич на фото: 3
